# %%
# import packages
import pandas as pd
import numpy as np
import keras as keras
from scipy.stats import norm

# to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

# read the file, Log Returns
df_log = pd.read_csv('Log_Industry_Return_Data.csv')
df_log.head(1)
# Out:
#    Time_number        Date     Agric     Food      FabPr    Mach      ElcEq  \
# 0            1  01/07/1963  0.008563  0.006479 -0.003606  0.00777  0.005087
#
#       Autos     Guns      Gold      Mines    Coal
# 0  0.007968  0.008067 -0.001902 -0.005314  0.01479

# %%
# Number of days and simulations
t_intervals = 1825
iterations = 10

# Imagine closing price of €100
inital = 100

# %%
# Agric is column index 2
df_log.iloc[0,2]
# Out:
# 0.008563231

# %%
# Agric
ag_df = df_log.iloc[:,2]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\Agric_Simulation.xlsx", 
               index=False)

# %%
# Food
ag_df = df_log.iloc[:,3]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\Food_Simulation.xlsx", 
               index=False)

# %%
# FabPr
ag_df = df_log.iloc[:,4]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\FabPr_Simulation.xlsx", 
               index=False)

# %%
# Mach
ag_df = df_log.iloc[:,5]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\Mach_Simulation.xlsx", 
               index=False)

# %%
# ElcEq
ag_df = df_log.iloc[:,6]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\ElcEq_Simulation.xlsx", 
               index=False)

# %%
# Autos
ag_df = df_log.iloc[:,7]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\Autos_Simulation.xlsx", 
               index=False)

# %%
# Guns
ag_df = df_log.iloc[:,8]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\Guns_Simulation.xlsx", 
               index=False)

# %%
# Gold
ag_df = df_log.iloc[:,9]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\Gold_Simulation.xlsx", 
               index=False)

# %%
# Mines
ag_df = df_log.iloc[:,10]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\Mines_Simulation.xlsx", 
               index=False)

# %%
# Coal
ag_df = df_log.iloc[:,11]
u_ag = ag_df.mean()
v_ag = ag_df.var()
drift_ag = np.array(u_ag - (0.5 * v_ag))
std_ag = np.array(ag_df.std())

# Generate ag_returns 
ag_returns = np.exp(drift_ag + std_ag * norm.ppf(np.random.rand(t_intervals, iterations)))

# Find prices
ag_price_list = np.zeros_like(ag_returns)
ag_price_list[0] = inital

for t in range(1, t_intervals):
    ag_price_list[t] = ag_price_list[t - 1] * ag_returns[t]

# plot results
plt.plot(ag_price_list)

# turn to dataframe then to csv
ag_simulatedf = pd.DataFrame(ag_price_list)
ag_simulatedf.to_excel(r"C:\Users\jacka\Desktop\College Final Year\Semester 1\STAT 40920\Group Project\Simulations\Coal_Simulation.xlsx", 
               index=False)
